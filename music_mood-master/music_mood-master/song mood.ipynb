# %% [markdown]
# Spotify object: https://developer.spotify.com/documentation/web-api/reference/#object-audiofeaturesobject

# %% [markdown]
# Spotipy Doc: https://spotipy.readthedocs.io/en/2.13.0/?highlight=audio_features#installation

# %% [markdown]
# Spotify App: https://developer.spotify.com/dashboard/applications/cb29f52a31a54b7b8d2337e343fa8c0b

# %%
import spotipy

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
SPOTIPY_CLIENT_ID='cb29f52a31a54b7b8d2337e343fa8c0b'
SPOTIPY_CLIENT_SECRET='eb5b07c2ab984688aba0216658d2e033'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID,
                                                           client_secret=SPOTIPY_CLIENT_SECRET))

# %% [markdown]
# https://developer.spotify.com/console/get-playlist/?playlist_id=37i9dQZF1DX3rxVfibe1L0%3Fsi%3D49f014ae3be3487b&market=&fields=&additional_types=

# %%
playlist_id = '37i9dQZF1DX3rxVfibe1L0'

# %%
playlist = sp.playlist_tracks(playlist_id)

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3rxVfibe1L0/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-06-18T04:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#        'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#        'id': '64KEffDW9EtZ1y2vBYgq8T',
#        'name': 'Marshmello',
#        'type': 'artist',
#        'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#        'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
# ...

# %%
playlist['items']
# Out:
# [{'added_at': '2021-06-18T04:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#       'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#       'id': '64KEffDW9EtZ1y2vBYgq8T',
#       'name': 'Marshmello',
#       'type': 'artist',
#       'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
# ...

# %%
playlist_ids = {}
for item in playlist['items']:
#     print(item['track']['name'], item['track']['id'])
    playlist_ids[item['track']['id']] = item['track']['name']

# %%
playlist_ids.keys()
# Out:
# dict_keys(['4qu63nuBpdn0qHUHuObEj1', '6Skh3CBum0pZw9TOr7FQnX', '7xbWAw3LMgRMn4omR5yVn3', '7rpNuuoMbid56XkDsx2FjE', '3KdoeNlEN0BoAKWzaRLNZa', '1jgu8MFTEGdL1wjw9gZj5y', '4ZTTUAjJCd4NMZmIU7RB4c', '1GkHyypTFkUf0QQKwYoXH4', '6SGG5AxHShqSYiV9fCWpZz', '6UelLqGlWMcVH1E5c4H7lY', '5Ne1q9Hv3l2NHBA3Agt8WT', '3Z8FwOEN59mRMxDCtb8N0A', '31qCy5ZaophVA81wtlwLc4', '463CkQjx2Zk1yXoBuierM9', '472vIK1ldetTxRxG3ovaiY', '1fah1uAs7HeTYDlNftKr3K', '5u1n1kITHCxxp8twBcZxWy', '0ycFQvBTfuo1LCdG0HhszL', '0zzVTGyRrWpQu8Fr28NRAv', '140XpWSdJ0jZEbLj9iVnPA', '0DmAvNCAK08oCi7miSZUIY', '5f1joOtoMeyppIcJGZQvqJ', '37BZB0z9T8Xu7U3e65qxFy', '28Tv8zltFDr5wBCG3Pfky4', '4rVW6XqAsSaf5vOwc8FREW', '02MWAaffLxlfxAUY7c5dvx', '7k6tAZp4m93oswrPqSfBbc', '0TrPqhAMoaKUFLR7iYDokf', '2UbVnbE5FH6008mAm6Mmgw', '5id3Rqn7SPj1LX4FfY4nGz', '44l9nnCVvOQBbWG6tDViKl', '7hcYAIyiOVdmRhpGtSJRTP', '20d27F17AZOxTJOEHAVK2Y', '02VHspkXhhH1QCInRWWIfr', '4iJyoBOLtHqaGxP12qzhQI', '2kAIpGWnlFLQh48iut6Zzq', '5K6Ssv4Z3zRvxt0P6EKUAP', '0l4AReW2LuX0yStPfgQgSR',
# ...

# %%
audio_features = sp.audio_features(playlist_ids.keys())

# %%
for audio_feature in audio_features:
    audio_feature['name']  = playlist_ids[audio_feature['id']]

# %%
audio_features
# Out:
# [{'danceability': 0.721,
#   'energy': 0.738,
#   'key': 7,
#   'loudness': -4.77,
#   'mode': 1,
#   'speechiness': 0.0403,
#   'acousticness': 0.00226,
#   'instrumentalness': 4.41e-06,
#   'liveness': 0.118,
#   'valence': 0.637,
#   'tempo': 119.976,
#   'type': 'audio_features',
#   'id': '4qu63nuBpdn0qHUHuObEj1',
#   'uri': 'spotify:track:4qu63nuBpdn0qHUHuObEj1',
#   'track_href': 'https://api.spotify.com/v1/tracks/4qu63nuBpdn0qHUHuObEj1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qu63nuBpdn0qHUHuObEj1',
#   'duration_ms': 154983,
#   'time_signature': 4,
#   'name': 'Leave Before You Love Me (with Jonas Brothers)'},
#  {'danceability': 0.497,
#   'energy': 0.757,
#   'key': 11,
#   'loudness': -4.189,
#   'mode': 1,
#   'speechiness': 0.127,
#   'acousticness': 0.0449,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.507,
#   'tempo': 169.902,
#   'type': 'audio_features',
#   'id': '6Skh3CBum0pZw9TOr7FQnX',
# ...

# %%
import pandas as pd

# %%
df_audio_features = pd.json_normalize(audio_features)

# %%
df_audio_features
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.721   0.738    7    -4.770     1       0.0403       0.00226
# 1          0.497   0.757   11    -4.189     1       0.1270       0.04490
# 2          0.580   0.586    1    -6.883     1       0.0357       0.34400
# 3          0.443   0.582    2    -6.020     1       0.0482       0.03010
# 4          0.735   0.470    4    -9.405     1       0.1000       0.26600
# ..           ...     ...  ...       ...   ...          ...           ...
# 73         0.674   0.774   11    -7.567     0       0.0892       0.06860
# 74         0.727   0.832    9    -4.327     0       0.0366       0.18100
# 75         0.759   0.459    8    -5.187     1       0.0948       0.00323
# 76         0.693   0.678    8    -7.159     1       0.0324       0.01510
# 77         0.660   0.733    0    -4.619     1       0.0359       0.24800
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
url = 'https://p.scdn.co/mp3-preview/663d2c8b563f6e0b4e7f4d76486f4d9ecd66dc9c?cid=774b29d4f13844c495f206cafdad9c86'

# %%
import urllib

# %%
urllib.request.urlretrieve(url, "song_preview_1.mp3")
# Out:
# ('song_preview_1.mp3', <http.client.HTTPMessage at 0x7fe197fc3e10>)

# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
# import  PIL as pillow
# from PIL import Image
import pathlib
import csv 
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder, StandardScaler
# from keras import layers
# from keras import layers
# import keras 
# from keras.models import Sequential
# import warnings
# warnings.filterwarnings('ignore')

# %%
# cmap = plt.get_cmap('inferno')
# plt.figure(figsize=(8,8))
# genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
# for g in genres:
#     pathlib.Path(f'./{g}').mkdir(parents=True, exist_ok=True)
#     for filename in os.listdir(f'./{g}'):
#         songname = f'./{g}/{filename}'
#         print(songname)
#         y, sr = librosa.load(songname, mono=True, duration=5)
#         plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
#         plt.axis('off');
#         plt.show()
# #         plt.savefig(f'img_data/{g}/{filename[:-3].replace(".", "")}.png')
# #         plt.clf()

# %%
cmap = plt.get_cmap('inferno')
plt.figure(figsize=(8,8))
pathlib.Path(f'.').mkdir(parents=True, exist_ok=True)
for filename in os.listdir('.'):
    if filename.endswith(".mp3"):
        songname = f'./{filename}'
        print(songname)
        y, sr = librosa.load(songname, mono=True, duration=5)
        plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
        plt.axis('off');
        plt.show()
#         plt.savefig(f'img_data/{g}/{filename[:-3].replace(".", "")}.png')
#         plt.clf()
# Out:
# ./song_preview.mp3
# /Users/sara/opt/miniconda3/envs/music_mood/lib/python3.7/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ./song_preview_1.mp3
# /Users/sara/opt/miniconda3/envs/music_mood/lib/python3.7/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
songname = f'./song_preview_1.mp3'
y, sr = librosa.load(songname)
# Out:
# /Users/sara/opt/miniconda3/envs/music_mood/lib/python3.7/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');

# %%
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr)

# %%
import IPython.display as ipd
ipd.Audio(songname)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
